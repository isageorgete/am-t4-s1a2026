# %% [markdown]
# <a href="https://colab.research.google.com/github/isageorgete/am-t4-s1a2026/blob/main/Exercicio0428.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

API_KEY = 'UC2NXM2QGYB1ETR5'
SYMBOL = ['NFLX', 'AAPL', 'GOOGL', 'AMZN', 'MSFT']
lista_emp = []

for simbolo in EMPRESAS:
  print(f'Extraindo dados de {simbolo}')
  time.sleep(5)
  url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={SYMBOL}&apikey={API_KEY}'
  r = requests.get(url)
  base = r.json()

  if 'Global Quote' in base:
   temporario = pd.DataFrame([base['Global Quote']])
   lista_emp.append(temporario)


   base_empresas = pd.concat(lista_emp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1447/1981664867.py in <cell line: 0>()
#       6 lista_emp = []
#       7
# ----> 8 for simbolo in EMPRESAS:
#       9   print(f'Extraindo dados de {simbolo}')
#      10   time.sleep(5)
#
# NameError: name 'EMPRESAS' is not defined

# %%
base_alpha_netflix = pd.DataFrame.from_dict([base['Global Quote']])
base_alpha_netflix
# Out:
#   01. symbol 02. open 03. high  04. low 05. price 06. volume  \
# 0       NFLX  92.0500  92.8400  91.3000   91.3700   29707439
#
#   07. latest trading day 08. previous close 09. change 10. change percent
# 0             2026-04-27            92.4400    -1.0700           -1.1575%
